# %% [markdown]
# <a href="https://colab.research.google.com/github/byeasmin/python_2026_update/blob/main/python_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming Language
#
# *   Multi-Paradigm Language
# *   Object Oriented
# *   Funtional programming
# *   Structured Programming
# *   Procedural Oriented
# *   High Level Language
# *   General Purpose Language
#
# **1991: Python Released**

# %% [markdown]
# # Python - Command Prompt

# %% [markdown]
# ![Screenshot 2026-02-10 232819.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 084041.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 091627.png](data:image/png;base64,...)

# %% [markdown]
# # Variables - Command Prompt

# %% [markdown]
# ![Screenshot 2026-02-11 092023.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 093725.png](data:image/png;base64,...)

# %% [markdown]
# # String

# %% [markdown]
# ![Screenshot 2026-02-11 094632.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 095157.png](data:image/png;base64,...)

# %% [markdown]
# # Windows PowerShell

# %% [markdown]
# ![Screenshot 2026-02-11 095925.png](data:image/png;base64,...)

# %% [markdown]
# # CMD
#
#
# *   for printing \ - use \\
# *   for printing a string - use ''
# *   for printing " " - use \
# *   for printing ' - use ""

# %% [markdown]
# ![Screenshot 2026-02-11 095756.png](data:image/png;base64,...)

# %% [markdown]
# # More on String

# %% [markdown]
# **String literals:**
#
#
# *   String literals in python are surrounded by either single quotation marks, or double quotation marks. 'hello' is the same as "hello".
