# %% [markdown]
# <a href="https://colab.research.google.com/github/byeasmin/python_2026_update/blob/main/python_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming Language
#
# *   Multi-Paradigm Language
# *   Object Oriented
# *   Funtional programming
# *   Structured Programming
# *   Procedural Oriented
# *   High Level Language
# *   General Purpose Language
#
# **1991: Python Released**

# %% [markdown]
# # Python - Command Prompt

# %% [markdown]
# ![Screenshot 2026-02-10 232819.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 084041.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 091627.png](data:image/png;base64,...)

# %% [markdown]
# # Variables - Command Prompt

# %% [markdown]
# ![Screenshot 2026-02-11 092023.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 093725.png](data:image/png;base64,...)

# %% [markdown]
# # String

# %% [markdown]
# ![Screenshot 2026-02-11 094632.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-11 095157.png](data:image/png;base64,...)

# %% [markdown]
# # Windows PowerShell

# %% [markdown]
# ![Screenshot 2026-02-11 095925.png](data:image/png;base64,...)

# %% [markdown]
# # CMD
#
#
# *   for printing \ - use \\
# *   for printing a string - use ''
# *   for printing " " - use \
# *   for printing ' - use ""

# %% [markdown]
# ![Screenshot 2026-02-11 095756.png](data:image/png;base64,...)

# %% [markdown]
# # More on String

# %% [markdown]
# **String literals:**
#
#
# *   String literals in python are surrounded by either single quotation marks, or double quotation marks. 'hello' is the same as "hello".

# %% [markdown]
# **String Literal & a variable**

# %% [markdown]
# ![Screenshot 2026-02-13 090821.png](data:image/png;base64,...)

# %% [markdown]
# # Concatenate String

# %% [markdown]
# ![Screenshot 2026-02-17 230917.png](data:image/png;base64,...)

# %% [markdown]
# # Find index

# %% [markdown]
# ![Screenshot 2026-02-17 233413.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-17 234647.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-02-18 000022.png](data:image/png;base64,...)

# %% [markdown]
# **Slicing in Python does NOT include the ending index.**

# %% [markdown]
# ![Screenshot 2026-02-20 082558.png](data:image/png;base64,...)

# %% [markdown]
# **String - Sequence of characters/collection of characters**
#
# **Can Store multiple values in one List**

# %% [markdown]
# ![Screenshot 2026-02-20 092146.png](data:image/png;base64,...)

# %% [markdown]
# # List

# %% [markdown]
# ![Screenshot 2026-02-20 094119.png](data:image/png;base64,...)

# %% [markdown]
# **Append()**
#
#
# *   Append means to add something at the end.
# *   In Python, append() is used to add a new item to the end of a list.
# *   append = add to the end.

# %% [markdown]
# ![Screenshot 2026-02-20 095639.png](data:image/png;base64,...)

# %% [markdown]
# **Count()**
#
#
# *   count() means to count how many times a value appears.
# *   In Python, count() is used to count how many times a specific item appears in a list or string.
# *   count() = tell me how many times this value appears.

# %% [markdown]
# ![Screenshot 2026-02-20 101644.png](data:image/png;base64,...)

# %% [markdown]
# **Insert()**
# *   insert() means to add a value at a specific position.
# *   In Python, insert() is used to put an item into a list at a chosen index.
# *   insert() = add a value at a specific position.

# %% [markdown]
# ![Screenshot 2026-02-20 102242.png](data:image/png;base64,...)

# %% [markdown]
# # Difference Between append() and insert()
# **Both are used to add items to a list, but they work differently.**
#
#
#
# 1.  append()
# *   Adds item at the end.
# *   No position needed.
# 2.  insert()
# *   Adds item at a specific position.
# *   You must give the index.
#
#
# **append() = add at the end**
#
# **insert() = add at a specific position**

# %% [markdown]
# # Some Confusion About list & String
#
#
# *   When we're trying to work with string & when we're trying to change the values or the characters of a string it was not allowing it bcz, it was immutable.
# *   On the other hand List is Mutable. So mutable simply means, it can be changed.
# *   So we're able to change the value of list bcz, it's mutable.

# %% [markdown]
# **Remove()**
# *   remove() means to delete a specific value from a list. It removes the first occurrence of that value.
# *   remove() = delete the first matching value from a list.

# %% [markdown]
# ![Screenshot 2026-02-20 104403.png](data:image/png;base64,...)

# %% [markdown]
# **pop()**
# *   The pop() method in Python removes an element from a list at a specified index and returns it.
# *   pop() is a method to remove an element from a list by index and return it.
# *   pop() = remove an item by index and return it.

# %% [markdown]
# ![Screenshot 2026-02-20 104922.png](data:image/png;base64,...)

# %% [markdown]
# **list is similar to string.**
